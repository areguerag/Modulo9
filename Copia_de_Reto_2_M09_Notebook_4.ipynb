# %% [markdown]
# # MÁSTER en Behavioral Data Science - **Módulo 9: Aprendizaje Profundo** - Notebook 4/4.
# Autor: **Meysam Madadi**
#
# Colaborador: Julio C. S. Jacques Junior
#
# ---

# %% [markdown]
# # **Los objetivos de este Jupyter notebook**
# - Crear nuestro modelo para datos multimodales (texto e imagen).
# - Predecir personalidad aparente a partir de datos multimodales.
# - Visualizar los resultados.

# %% [markdown]
# ## Cargando y descomprimiendo los datos, e importando las librerias requeridas
#
# El número total de muestras de imágenes por video es 4. Podemos definir cuántas imágenes se utilizarán para entrenamiento/prueba. Para esto podríamos cambiar **"n\_frames"** en la siguiente celda por un valor en el rango [1..4].
#
# - Todos los modelos se implementan y entrenan utilizando Keras.
# - Reimplementamos la función **model.fit()** en una nueva clase, llamada **MyModel**, disponible en el archivo **myfunctions.py**. Esto se debe a algunos problemas técnicos que tuvimos, muy probablemente causados por las limitaciones de memoria de Colab.

# %%
# Download and unzip the data
# !wget https://data.chalearnlap.cvc.uab.cat/Colab_2021/UBmasterBDS/data_final.zip
# !unzip ./data_final.zip

# Download the file in which we have reimplemented Model class
# !wget https://data.chalearnlap.cvc.uab.cat/Colab_2021/UBmasterBDS/myfunctions.py
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: data_final/validation/qJ6_xSx9kCM.002/annotation.npy
#   inflating: data_final/validation/qJ6_xSx9kCM.002/transcription_features.npy
#    creating: data_final/validation/QJcc95Y0XPw.002/
#   inflating: data_final/validation/QJcc95Y0XPw.002/001.jpg
#   inflating: data_final/validation/QJcc95Y0XPw.002/115.jpg
#   inflating: data_final/validation/QJcc95Y0XPw.002/229.jpg
#   inflating: data_final/validation/QJcc95Y0XPw.002/343.jpg
#   inflating: data_final/validation/QJcc95Y0XPw.002/annotation.npy
#   inflating: data_final/validation/QJcc95Y0XPw.002/transcription_features.npy
#    creating: data_final/validation/qjU3GX3jgSY.002/
#   inflating: data_final/validation/qjU3GX3jgSY.002/001.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.002/115.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.002/229.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.002/343.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.002/annotation.npy
#   inflating: data_final/validation/qjU3GX3jgSY.002/transcription_features.npy
#    creating: data_final/validation/qjU3GX3jgSY.003/
#   inflating: data_final/validation/qjU3GX3jgSY.003/001.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.003/115.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.003/229.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.003/343.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.003/annotation.npy
#   inflating: data_final/validation/qjU3GX3jgSY.003/transcription_features.npy
#    creating: data_final/validation/qjU3GX3jgSY.004/
#   inflating: data_final/validation/qjU3GX3jgSY.004/001.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.004/115.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.004/229.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.004/343.jpg
#   inflating: data_final/validation/qjU3GX3jgSY.004/annotation.npy
#   inflating: data_final/validation/qjU3GX3jgSY.004/transcription_features.npy
#    creating: data_final/validation/qjWi69HY2Fc.000/
#   inflating: data_final/validation/qjWi69HY2Fc.000/001.jpg
#   inflating: data_final/validation/qjWi69HY2Fc.000/115.jpg
#   inflating: data_final/validation/qjWi69HY2Fc.000/229.jpg
#   inflating: data_final/validation/qjWi69HY2Fc.000/343.jpg
#   inflating: data_final/validation/qjWi69HY2Fc.000/annotation.npy
#   inflating: data_final/validation/qjWi69HY2Fc.000/transcription_features.npy
#    creating: data_final/validation/Qkao4XiSflU.003/
#   inflating: data_final/validation/Qkao4XiSflU.003/001.jpg
#   inflating: data_final/validation/Qkao4XiSflU.003/115.jpg
#   inflating: data_final/validation/Qkao4XiSflU.003/229.jpg
#   inflating: data_final/validation/Qkao4XiSflU.003/343.jpg
#   inflating: data_final/validation/Qkao4XiSflU.003/annotation.npy
#   inflating: data_final/validation/Qkao4XiSflU.003/transcription_features.npy
#    creating: data_final/validation/QKcx5msA7iA.000/
#   inflating: data_final/validation/QKcx5msA7iA.000/001.jpg
#   inflating: data_final/validation/QKcx5msA7iA.000/092.jpg
#   inflating: data_final/validation/QKcx5msA7iA.000/183.jpg
#   inflating: data_final/validation/QKcx5msA7iA.000/274.jpg
#   inflating: data_final/validation/QKcx5msA7iA.000/annotation.npy
#   inflating: data_final/validation/QKcx5msA7iA.000/transcription_features.npy
#    creating: data_final/validation/QKcx5msA7iA.003/
#   inflating: data_final/validation/QKcx5msA7iA.003/001.jpg
#   inflating: data_final/validation/QKcx5msA7iA.003/092.jpg
#   inflating: data_final/validation/QKcx5msA7iA.003/183.jpg
#   inflating: data_final/validation/QKcx5msA7iA.003/274.jpg
#   inflating: data_final/validation/QKcx5msA7iA.003/annotation.npy
#   inflating: data_final/validation/QKcx5msA7iA.003/transcription_features.npy
#    creating: data_final/validation/QKcx5msA7iA.004/
#   inflating: data_final/validation/QKcx5msA7iA.004/001.jpg
#   inflating: data_final/validation/QKcx5msA7iA.004/092.jpg
#   inflating: data_final/validation/QKcx5msA7iA.004/183.jpg
#   inflating: data_final/validation/QKcx5msA7iA.004/274.jpg
#   inflating: data_final/validation/QKcx5msA7iA.004/annotation.npy
#   inflating: data_final/validation/QKcx5msA7iA.004/transcription_features.npy
#    creating: data_final/validation/QKlawwZQK9M.000/
#   inflating: data_final/validation/QKlawwZQK9M.000/001.jpg
#   inflating: data_final/validation/QKlawwZQK9M.000/096.jpg
#   inflating: data_final/validation/QKlawwZQK9M.000/191.jpg
#   inflating: data_final/validation/QKlawwZQK9M.000/286.jpg
#   inflating: data_final/validation/QKlawwZQK9M.000/annotation.npy
#   inflating: data_final/validation/QKlawwZQK9M.000/transcription_features.npy
#    creating: data_final/validation/QKlawwZQK9M.001/
#   inflating: data_final/validation/QKlawwZQK9M.001/001.jpg
#   inflating: data_final/validation/QKlawwZQK9M.001/096.jpg
#   inflating: data_final/validation/QKlawwZQK9M.001/191.jpg
#   inflating: data_final/validation/QKlawwZQK9M.001/286.jpg
#   inflating: data_final/validation/QKlawwZQK9M.001/annotation.npy
#   inflating: data_final/validation/QKlawwZQK9M.001/transcription_features.npy
#    creating: data_final/validation/QKluS-uQIaM.002/
#   inflating: data_final/validation/QKluS-uQIaM.002/001.jpg
#   inflating: data_final/validation/QKluS-uQIaM.002/115.jpg
#   inflating: data_final/validation/QKluS-uQIaM.002/229.jpg
#   inflating: data_final/validation/QKluS-uQIaM.002/343.jpg
#   inflating: data_final/validation/QKluS-uQIaM.002/annotation.npy
#   inflating: data_final/validation/QKluS-uQIaM.002/transcription_features.npy
#    creating: data_final/validation/qkmEt0ofGq8.002/
#   inflating: data_final/validation/qkmEt0ofGq8.002/001.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.002/115.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.002/229.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.002/343.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.002/annotation.npy
#   inflating: data_final/validation/qkmEt0ofGq8.002/transcription_features.npy
#    creating: data_final/validation/qkmEt0ofGq8.003/
#   inflating: data_final/validation/qkmEt0ofGq8.003/001.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.003/115.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.003/229.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.003/343.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.003/annotation.npy
#   inflating: data_final/validation/qkmEt0ofGq8.003/transcription_features.npy
#    creating: data_final/validation/qkmEt0ofGq8.004/
#   inflating: data_final/validation/qkmEt0ofGq8.004/001.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.004/115.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.004/229.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.004/343.jpg
#   inflating: data_final/validation/qkmEt0ofGq8.004/annotation.npy
#   inflating: data_final/validation/qkmEt0ofGq8.004/transcription_features.npy
#    creating: data_final/validation/qktahyrtrFs.000/
#   inflating: data_final/validation/qktahyrtrFs.000/001.jpg
#   inflating: data_final/validation/qktahyrtrFs.000/115.jpg
#   inflating: data_final/validation/qktahyrtrFs.000/229.jpg
#   inflating: data_final/validation/qktahyrtrFs.000/343.jpg
#   inflating: data_final/validation/qktahyrtrFs.000/annotation.npy
#   inflating: data_final/validation/qktahyrtrFs.000/transcription_features.npy
#    creating: data_final/validation/qktahyrtrFs.001/
#   inflating: data_final/validation/qktahyrtrFs.001/001.jpg
#   inflating: data_final/validation/qktahyrtrFs.001/115.jpg
#   inflating: data_final/validation/qktahyrtrFs.001/229.jpg
#   inflating: data_final/validation/qktahyrtrFs.001/343.jpg
#   inflating: data_final/validation/qktahyrtrFs.001/annotation.npy
#   inflating: data_final/validation/qktahyrtrFs.001/transcription_features.npy
#    creating: data_final/validation/QlBgvZjbX30.000/
#   inflating: data_final/validation/QlBgvZjbX30.000/001.jpg
#   inflating: data_final/validation/QlBgvZjbX30.000/115.jpg
#   inflating: data_final/validation/QlBgvZjbX30.000/229.jpg
#   inflating: data_final/validation/QlBgvZjbX30.000/343.jpg
#   inflating: data_final/validation/QlBgvZjbX30.000/annotation.npy
#   inflating: data_final/validation/QlBgvZjbX30.000/transcription_features.npy
#    creating: data_final/validation/QlBgvZjbX30.002/
#   inflating: data_final/validation/QlBgvZjbX30.002/001.jpg
#   inflating: data_final/validation/QlBgvZjbX30.002/115.jpg
#   inflating: data_final/validation/QlBgvZjbX30.002/229.jpg
#   inflating: data_final/validation/QlBgvZjbX30.002/343.jpg
#   inflating: data_final/validation/QlBgvZjbX30.002/annotation.npy
#   inflating: data_final/validation/QlBgvZjbX30.002/transcription_features.npy
#    creating: data_final/validation/qLbOPbx33dk.001/
#   inflating: data_final/validation/qLbOPbx33dk.001/001.jpg
#   inflating: data_final/validation/qLbOPbx33dk.001/096.jpg
#   inflating: data_final/validation/qLbOPbx33dk.001/191.jpg
#   inflating: data_final/validation/qLbOPbx33dk.001/286.jpg
#   inflating: data_final/validation/qLbOPbx33dk.001/annotation.npy
#   inflating: data_final/validation/qLbOPbx33dk.001/transcription_features.npy
#    creating: data_final/validation/QlkTEWrSCBs.000/
#   inflating: data_final/validation/QlkTEWrSCBs.000/001.jpg
#   inflating: data_final/validation/QlkTEWrSCBs.000/096.jpg
#   inflating: data_final/validation/QlkTEWrSCBs.000/191.jpg
#   inflating: data_final/validation/QlkTEWrSCBs.000/286.jpg
#   inflating: data_final/validation/QlkTEWrSCBs.000/annotation.npy
#   inflating: data_final/validation/QlkTEWrSCBs.000/transcription_features.npy
#    creating: data_final/validation/qLV1a_611kA.004/
#   inflating: data_final/validation/qLV1a_611kA.004/001.jpg
#   inflating: data_final/validation/qLV1a_611kA.004/092.jpg
#   inflating: data_final/validation/qLV1a_611kA.004/183.jpg
#   inflating: data_final/validation/qLV1a_611kA.004/274.jpg
#   inflating: data_final/validation/qLV1a_611kA.004/annotation.npy
#   inflating: data_final/validation/qLV1a_611kA.004/transcription_features.npy
#    creating: data_final/validation/qMARpi60Hhs.000/
#   inflating: data_final/validation/qMARpi60Hhs.000/001.jpg
#   inflating: data_final/validation/qMARpi60Hhs.000/115.jpg
#   inflating: data_final/validation/qMARpi60Hhs.000/229.jpg
#   inflating: data_final/validation/qMARpi60Hhs.000/343.jpg
#   inflating: data_final/validation/qMARpi60Hhs.000/annotation.npy
#   inflating: data_final/validation/qMARpi60Hhs.000/transcription_features.npy
#    creating: data_final/validation/qMARpi60Hhs.004/
#   inflating: data_final/validation/qMARpi60Hhs.004/001.jpg
#   inflating: data_final/validation/qMARpi60Hhs.004/115.jpg
#   inflating: data_final/validation/qMARpi60Hhs.004/229.jpg
#   inflating: data_final/validation/qMARpi60Hhs.004/343.jpg
#   inflating: data_final/validation/qMARpi60Hhs.004/annotation.npy
#   inflating: data_final/validation/qMARpi60Hhs.004/transcription_features.npy
#    creating: data_final/validation/qmiBcHJpKR0.000/
#   inflating: data_final/validation/qmiBcHJpKR0.000/001.jpg
#   inflating: data_final/validation/qmiBcHJpKR0.000/115.jpg
#   inflating: data_final/validation/qmiBcHJpKR0.000/229.jpg
#   inflating: data_final/validation/qmiBcHJpKR0.000/343.jpg
#   inflating: data_final/validation/qmiBcHJpKR0.000/annotation.npy
#   inflating: data_final/validation/qmiBcHJpKR0.000/transcription_features.npy
#    creating: data_final/validation/qmiBcHJpKR0.003/
#   inflating: data_final/validation/qmiBcHJpKR0.003/001.jpg
#   inflating: data_final/validation/qmiBcHJpKR0.003/115.jpg
#   inflating: data_final/validation/qmiBcHJpKR0.003/229.jpg
#   inflating: data_final/validation/qmiBcHJpKR0.003/343.jpg
#   inflating: data_final/validation/qmiBcHJpKR0.003/annotation.npy
#   inflating: data_final/validation/qmiBcHJpKR0.003/transcription_features.npy
#    creating: data_final/validation/QMRAbwZCTfI.005/
#   inflating: data_final/validation/QMRAbwZCTfI.005/001.jpg
#   inflating: data_final/validation/QMRAbwZCTfI.005/096.jpg
#   inflating: data_final/validation/QMRAbwZCTfI.005/191.jpg
#   inflating: data_final/validation/QMRAbwZCTfI.005/286.jpg
#   inflating: data_final/validation/QMRAbwZCTfI.005/annotation.npy
#   inflating: data_final/validation/QMRAbwZCTfI.005/transcription_features.npy
#    creating: data_final/validation/QNVsr2mGwGs.001/
#   inflating: data_final/validation/QNVsr2mGwGs.001/001.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.001/092.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.001/183.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.001/274.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.001/annotation.npy
#   inflating: data_final/validation/QNVsr2mGwGs.001/transcription_features.npy
#    creating: data_final/validation/QNVsr2mGwGs.004/
#   inflating: data_final/validation/QNVsr2mGwGs.004/001.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.004/092.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.004/183.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.004/274.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.004/annotation.npy
#   inflating: data_final/validation/QNVsr2mGwGs.004/transcription_features.npy
#    creating: data_final/validation/QNVsr2mGwGs.005/
#   inflating: data_final/validation/QNVsr2mGwGs.005/001.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.005/092.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.005/183.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.005/274.jpg
#   inflating: data_final/validation/QNVsr2mGwGs.005/annotation.npy
#   inflating: data_final/validation/QNVsr2mGwGs.005/transcription_features.npy
#    creating: data_final/validation/QovE6L-C9VY.000/
#   inflating: data_final/validation/QovE6L-C9VY.000/001.jpg
#   inflating: data_final/validation/QovE6L-C9VY.000/092.jpg
#   inflating: data_final/validation/QovE6L-C9VY.000/183.jpg
#   inflating: data_final/validation/QovE6L-C9VY.000/274.jpg
#   inflating: data_final/validation/QovE6L-C9VY.000/annotation.npy
#   inflating: data_final/validation/QovE6L-C9VY.000/transcription_features.npy
#    creating: data_final/validation/qoztP0w5-Vo.000/
#   inflating: data_final/validation/qoztP0w5-Vo.000/001.jpg
#   inflating: data_final/validation/qoztP0w5-Vo.000/115.jpg
#   inflating: data_final/validation/qoztP0w5-Vo.000/229.jpg
#   inflating: data_final/validation/qoztP0w5-Vo.000/343.jpg
#   inflating: data_final/validation/qoztP0w5-Vo.000/annotation.npy
#   inflating: data_final/validation/qoztP0w5-Vo.000/transcription_features.npy
#    creating: data_final/validation/qoztP0w5-Vo.005/
#   inflating: data_final/validation/qoztP0w5-Vo.005/001.jpg
#   inflating: data_final/validation/qoztP0w5-Vo.005/115.jpg
#   inflating: data_final/validation/qoztP0w5-Vo.005/229.jpg
#   inflating: data_final/validation/qoztP0w5-Vo.005/343.jpg
#   inflating: data_final/validation/qoztP0w5-Vo.005/annotation.npy
#   inflating: data_final/validation/qoztP0w5-Vo.005/transcription_features.npy
#    creating: data_final/validation/qoZwA4ESb7g.000/
#   inflating: data_final/validation/qoZwA4ESb7g.000/001.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.000/115.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.000/229.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.000/343.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.000/annotation.npy
#   inflating: data_final/validation/qoZwA4ESb7g.000/transcription_features.npy
#    creating: data_final/validation/qoZwA4ESb7g.001/
#   inflating: data_final/validation/qoZwA4ESb7g.001/001.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.001/115.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.001/229.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.001/343.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.001/annotation.npy
#   inflating: data_final/validation/qoZwA4ESb7g.001/transcription_features.npy
#    creating: data_final/validation/qoZwA4ESb7g.003/
#   inflating: data_final/validation/qoZwA4ESb7g.003/001.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.003/115.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.003/229.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.003/343.jpg
#   inflating: data_final/validation/qoZwA4ESb7g.003/annotation.npy
#   inflating: data_final/validation/qoZwA4ESb7g.003/transcription_features.npy
#    creating: data_final/validation/qP1UtCbMaW4.003/
#   inflating: data_final/validation/qP1UtCbMaW4.003/001.jpg
#   inflating: data_final/validation/qP1UtCbMaW4.003/115.jpg
#   inflating: data_final/validation/qP1UtCbMaW4.003/229.jpg
#   inflating: data_final/validation/qP1UtCbMaW4.003/343.jpg
#   inflating: data_final/validation/qP1UtCbMaW4.003/annotation.npy
#   inflating: data_final/validation/qP1UtCbMaW4.003/transcription_features.npy
#    creating: data_final/validation/qP8YzH6LT9c.001/
#   inflating: data_final/validation/qP8YzH6LT9c.001/001.jpg
#   inflating: data_final/validation/qP8YzH6LT9c.001/092.jpg
#   inflating: data_final/validation/qP8YzH6LT9c.001/183.jpg
#   inflating: data_final/validation/qP8YzH6LT9c.001/274.jpg
#   inflating: data_final/validation/qP8YzH6LT9c.001/annotation.npy
#   inflating: data_final/validation/qP8YzH6LT9c.001/transcription_features.npy
#    creating: data_final/validation/QpA0gj1y6KE.000/
#   inflating: data_final/validation/QpA0gj1y6KE.000/001.jpg
#   inflating: data_final/validation/QpA0gj1y6KE.000/096.jpg
#   inflating: data_final/validation/QpA0gj1y6KE.000/191.jpg
#   inflating: data_final/validation/QpA0gj1y6KE.000/286.jpg
#   inflating: data_final/validation/QpA0gj1y6KE.000/annotation.npy
#   inflating: data_final/validation/QpA0gj1y6KE.000/transcription_features.npy
#    creating: data_final/validation/qpwcdPnPeFM.004/
#   inflating: data_final/validation/qpwcdPnPeFM.004/001.jpg
#   inflating: data_final/validation/qpwcdPnPeFM.004/115.jpg
#   inflating: data_final/validation/qpwcdPnPeFM.004/229.jpg
#   inflating: data_final/validation/qpwcdPnPeFM.004/343.jpg
#   inflating: data_final/validation/qpwcdPnPeFM.004/annotation.npy
#   inflating: data_final/validation/qpwcdPnPeFM.004/transcription_features.npy
#    creating: data_final/validation/qPzzmcuf-VI.000/
#   inflating: data_final/validation/qPzzmcuf-VI.000/001.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.000/115.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.000/229.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.000/343.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.000/annotation.npy
#   inflating: data_final/validation/qPzzmcuf-VI.000/transcription_features.npy
#    creating: data_final/validation/qPzzmcuf-VI.004/
#   inflating: data_final/validation/qPzzmcuf-VI.004/001.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.004/115.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.004/229.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.004/343.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.004/annotation.npy
#   inflating: data_final/validation/qPzzmcuf-VI.004/transcription_features.npy
#    creating: data_final/validation/qPzzmcuf-VI.005/
#   inflating: data_final/validation/qPzzmcuf-VI.005/001.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.005/115.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.005/229.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.005/343.jpg
#   inflating: data_final/validation/qPzzmcuf-VI.005/annotation.npy
#   inflating: data_final/validation/qPzzmcuf-VI.005/transcription_features.npy
#    creating: data_final/validation/Qqc1539E6rs.002/
#   inflating: data_final/validation/Qqc1539E6rs.002/001.jpg
#   inflating: data_final/validation/Qqc1539E6rs.002/096.jpg
#   inflating: data_final/validation/Qqc1539E6rs.002/191.jpg
#   inflating: data_final/validation/Qqc1539E6rs.002/286.jpg
#   inflating: data_final/validation/Qqc1539E6rs.002/annotation.npy
#   inflating: data_final/validation/Qqc1539E6rs.002/transcription_features.npy
#    creating: data_final/validation/Qqc1539E6rs.003/
#   inflating: data_final/validation/Qqc1539E6rs.003/001.jpg
#   inflating: data_final/validation/Qqc1539E6rs.003/096.jpg
#   inflating: data_final/validation/Qqc1539E6rs.003/191.jpg
#   inflating: data_final/validation/Qqc1539E6rs.003/286.jpg
#   inflating: data_final/validation/Qqc1539E6rs.003/annotation.npy
#   inflating: data_final/validation/Qqc1539E6rs.003/transcription_features.npy
#    creating: data_final/validation/Qqc1539E6rs.005/
#   inflating: data_final/validation/Qqc1539E6rs.005/001.jpg
#   inflating: data_final/validation/Qqc1539E6rs.005/096.jpg
#   inflating: data_final/validation/Qqc1539E6rs.005/191.jpg
#   inflating: data_final/validation/Qqc1539E6rs.005/286.jpg
#   inflating: data_final/validation/Qqc1539E6rs.005/annotation.npy
#   inflating: data_final/validation/Qqc1539E6rs.005/transcription_features.npy
#    creating: data_final/validation/QqTw0lnrtBo.002/
#   inflating: data_final/validation/QqTw0lnrtBo.002/001.jpg
#   inflating: data_final/validation/QqTw0lnrtBo.002/115.jpg
#   inflating: data_final/validation/QqTw0lnrtBo.002/229.jpg
#   inflating: data_final/validation/QqTw0lnrtBo.002/343.jpg
#   inflating: data_final/validation/QqTw0lnrtBo.002/annotation.npy
#   inflating: data_final/validation/QqTw0lnrtBo.002/transcription_features.npy
#    creating: data_final/validation/QqTw0lnrtBo.004/
#   inflating: data_final/validation/QqTw0lnrtBo.004/001.jpg
#   inflating: data_final/validation/QqTw0lnrtBo.004/115.jpg
#   inflating: data_final/validation/QqTw0lnrtBo.004/229.jpg
#   inflating: data_final/validation/QqTw0lnrtBo.004/343.jpg
#   inflating: data_final/validation/QqTw0lnrtBo.004/annotation.npy
#   inflating: data_final/validation/QqTw0lnrtBo.004/transcription_features.npy
#    creating: data_final/validation/QQzeQOoqO20.001/
#   inflating: data_final/validation/QQzeQOoqO20.001/001.jpg
#   inflating: data_final/validation/QQzeQOoqO20.001/115.jpg
#   inflating: data_final/validation/QQzeQOoqO20.001/229.jpg
#   inflating: data_final/validation/QQzeQOoqO20.001/343.jpg
#   inflating: data_final/validation/QQzeQOoqO20.001/annotation.npy
#   inflating: data_final/validation/QQzeQOoqO20.001/transcription_features.npy
#    creating: data_final/validation/QQzeQOoqO20.005/
#   inflating: data_final/validation/QQzeQOoqO20.005/001.jpg
#   inflating: data_final/validation/QQzeQOoqO20.005/115.jpg
#   inflating: data_final/validation/QQzeQOoqO20.005/229.jpg
#   inflating: data_final/validation/QQzeQOoqO20.005/343.jpg
#   inflating: data_final/validation/QQzeQOoqO20.005/annotation.npy
#   inflating: data_final/validation/QQzeQOoqO20.005/transcription_features.npy
#    creating: data_final/validation/qr1C43Ylavg.001/
#   inflating: data_final/validation/qr1C43Ylavg.001/001.jpg
#   inflating: data_final/validation/qr1C43Ylavg.001/092.jpg
#   inflating: data_final/validation/qr1C43Ylavg.001/183.jpg
#   inflating: data_final/validation/qr1C43Ylavg.001/274.jpg
#   inflating: data_final/validation/qr1C43Ylavg.001/annotation.npy
#   inflating: data_final/validation/qr1C43Ylavg.001/transcription_features.npy
#    creating: data_final/validation/qr1C43Ylavg.004/
#   inflating: data_final/validation/qr1C43Ylavg.004/001.jpg
#   inflating: data_final/validation/qr1C43Ylavg.004/092.jpg
#   inflating: data_final/validation/qr1C43Ylavg.004/183.jpg
#   inflating: data_final/validation/qr1C43Ylavg.004/274.jpg
#   inflating: data_final/validation/qr1C43Ylavg.004/annotation.npy
#   inflating: data_final/validation/qr1C43Ylavg.004/transcription_features.npy
#    creating: data_final/validation/qr1C43Ylavg.005/
#   inflating: data_final/validation/qr1C43Ylavg.005/001.jpg
#   inflating: data_final/validation/qr1C43Ylavg.005/092.jpg
#   inflating: data_final/validation/qr1C43Ylavg.005/183.jpg
#   inflating: data_final/validation/qr1C43Ylavg.005/274.jpg
#   inflating: data_final/validation/qr1C43Ylavg.005/annotation.npy
#   inflating: data_final/validation/qr1C43Ylavg.005/transcription_features.npy
#    creating: data_final/validation/qrjx2kxg6M4.002/
#   inflating: data_final/validation/qrjx2kxg6M4.002/001.jpg
#   inflating: data_final/validation/qrjx2kxg6M4.002/115.jpg
#   inflating: data_final/validation/qrjx2kxg6M4.002/229.jpg
#   inflating: data_final/validation/qrjx2kxg6M4.002/343.jpg
#   inflating: data_final/validation/qrjx2kxg6M4.002/annotation.npy
#   inflating: data_final/validation/qrjx2kxg6M4.002/transcription_features.npy
#    creating: data_final/validation/qRtKUGgULL8.000/
#   inflating: data_final/validation/qRtKUGgULL8.000/001.jpg
#   inflating: data_final/validation/qRtKUGgULL8.000/115.jpg
#   inflating: data_final/validation/qRtKUGgULL8.000/229.jpg
#   inflating: data_final/validation/qRtKUGgULL8.000/343.jpg
#   inflating: data_final/validation/qRtKUGgULL8.000/annotation.npy
#   inflating: data_final/validation/qRtKUGgULL8.000/transcription_features.npy
#    creating: data_final/validation/qRtKUGgULL8.002/
#   inflating: data_final/validation/qRtKUGgULL8.002/001.jpg
#   inflating: data_final/validation/qRtKUGgULL8.002/115.jpg
#   inflating: data_final/validation/qRtKUGgULL8.002/229.jpg
#   inflating: data_final/validation/qRtKUGgULL8.002/343.jpg
#   inflating: data_final/validation/qRtKUGgULL8.002/annotation.npy
#   inflating: data_final/validation/qRtKUGgULL8.002/transcription_features.npy
#    creating: data_final/validation/qRtKUGgULL8.005/
#   inflating: data_final/validation/qRtKUGgULL8.005/001.jpg
#   inflating: data_final/validation/qRtKUGgULL8.005/115.jpg
#   inflating: data_final/validation/qRtKUGgULL8.005/229.jpg
#   inflating: data_final/validation/qRtKUGgULL8.005/343.jpg
#   inflating: data_final/validation/qRtKUGgULL8.005/annotation.npy
#   inflating: data_final/validation/qRtKUGgULL8.005/transcription_features.npy
#    creating: data_final/validation/QS7TwjzkYiU.004/
#   inflating: data_final/validation/QS7TwjzkYiU.004/001.jpg
#   inflating: data_final/validation/QS7TwjzkYiU.004/092.jpg
#   inflating: data_final/validation/QS7TwjzkYiU.004/183.jpg
#   inflating: data_final/validation/QS7TwjzkYiU.004/274.jpg
#   inflating: data_final/validation/QS7TwjzkYiU.004/annotation.npy
#   inflating: data_final/validation/QS7TwjzkYiU.004/transcription_features.npy
#    creating: data_final/validation/qsb1j9bEENs.000/
#   inflating: data_final/validation/qsb1j9bEENs.000/001.jpg
#   inflating: data_final/validation/qsb1j9bEENs.000/092.jpg
#   inflating: data_final/validation/qsb1j9bEENs.000/183.jpg
#   inflating: data_final/validation/qsb1j9bEENs.000/274.jpg
#   inflating: data_final/validation/qsb1j9bEENs.000/annotation.npy
#   inflating: data_final/validation/qsb1j9bEENs.000/transcription_features.npy
#    creating: data_final/validation/qsb1j9bEENs.002/
#   inflating: data_final/validation/qsb1j9bEENs.002/001.jpg
#   inflating: data_final/validation/qsb1j9bEENs.002/092.jpg
#   inflating: data_final/validation/qsb1j9bEENs.002/183.jpg
#   inflating: data_final/validation/qsb1j9bEENs.002/274.jpg
#   inflating: data_final/validation/qsb1j9bEENs.002/annotation.npy
#   inflating: data_final/validation/qsb1j9bEENs.002/transcription_features.npy
#    creating: data_final/validation/qsd4GdeN_eY.001/
#   inflating: data_final/validation/qsd4GdeN_eY.001/001.jpg
#   inflating: data_final/validation/qsd4GdeN_eY.001/115.jpg
#   inflating: data_final/validation/qsd4GdeN_eY.001/229.jpg
#   inflating: data_final/validation/qsd4GdeN_eY.001/343.jpg
#   inflating: data_final/validation/qsd4GdeN_eY.001/annotation.npy
#   inflating: data_final/validation/qsd4GdeN_eY.001/transcription_features.npy
#    creating: data_final/validation/QsUj_OlGQ-0.000/
#   inflating: data_final/validation/QsUj_OlGQ-0.000/001.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.000/115.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.000/229.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.000/343.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.000/annotation.npy
#   inflating: data_final/validation/QsUj_OlGQ-0.000/transcription_features.npy
#    creating: data_final/validation/QsUj_OlGQ-0.002/
#   inflating: data_final/validation/QsUj_OlGQ-0.002/001.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.002/115.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.002/229.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.002/343.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.002/annotation.npy
#   inflating: data_final/validation/QsUj_OlGQ-0.002/transcription_features.npy
#    creating: data_final/validation/QsUj_OlGQ-0.004/
#   inflating: data_final/validation/QsUj_OlGQ-0.004/001.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.004/115.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.004/229.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.004/343.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.004/annotation.npy
#   inflating: data_final/validation/QsUj_OlGQ-0.004/transcription_features.npy
#    creating: data_final/validation/QsUj_OlGQ-0.005/
#   inflating: data_final/validation/QsUj_OlGQ-0.005/001.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.005/115.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.005/229.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.005/343.jpg
#   inflating: data_final/validation/QsUj_OlGQ-0.005/annotation.npy
#   inflating: data_final/validation/QsUj_OlGQ-0.005/transcription_features.npy
#    creating: data_final/validation/qtB-CogljAo.000/
#   inflating: data_final/validation/qtB-CogljAo.000/001.jpg
#   inflating: data_final/validation/qtB-CogljAo.000/096.jpg
#   inflating: data_final/validation/qtB-CogljAo.000/191.jpg
#   inflating: data_final/validation/qtB-CogljAo.000/286.jpg
#   inflating: data_final/validation/qtB-CogljAo.000/annotation.npy
#   inflating: data_final/validation/qtB-CogljAo.000/transcription_features.npy
#    creating: data_final/validation/qtB-CogljAo.001/
#   inflating: data_final/validation/qtB-CogljAo.001/001.jpg
#   inflating: data_final/validation/qtB-CogljAo.001/096.jpg
#   inflating: data_final/validation/qtB-CogljAo.001/191.jpg
#   inflating: data_final/validation/qtB-CogljAo.001/286.jpg
#   inflating: data_final/validation/qtB-CogljAo.001/annotation.npy
#   inflating: data_final/validation/qtB-CogljAo.001/transcription_features.npy
#    creating: data_final/validation/qtB-CogljAo.002/
#   inflating: data_final/validation/qtB-CogljAo.002/001.jpg
#   inflating: data_final/validation/qtB-CogljAo.002/096.jpg
#   inflating: data_final/validation/qtB-CogljAo.002/191.jpg
#   inflating: data_final/validation/qtB-CogljAo.002/286.jpg
#   inflating: data_final/validation/qtB-CogljAo.002/annotation.npy
#   inflating: data_final/validation/qtB-CogljAo.002/transcription_features.npy
#    creating: data_final/validation/qtB-CogljAo.003/
#   inflating: data_final/validation/qtB-CogljAo.003/001.jpg
#   inflating: data_final/validation/qtB-CogljAo.003/096.jpg
#   inflating: data_final/validation/qtB-CogljAo.003/191.jpg
#   inflating: data_final/validation/qtB-CogljAo.003/286.jpg
#   inflating: data_final/validation/qtB-CogljAo.003/annotation.npy
#   inflating: data_final/validation/qtB-CogljAo.003/transcription_features.npy
#    creating: data_final/validation/qtB-CogljAo.005/
#   inflating: data_final/validation/qtB-CogljAo.005/001.jpg
#   inflating: data_final/validation/qtB-CogljAo.005/096.jpg
#   inflating: data_final/validation/qtB-CogljAo.005/191.jpg
#   inflating: data_final/validation/qtB-CogljAo.005/286.jpg
#   inflating: data_final/validation/qtB-CogljAo.005/annotation.npy
#   inflating: data_final/validation/qtB-CogljAo.005/transcription_features.npy
#    creating: data_final/validation/QTtTAFqT-no.004/
#   inflating: data_final/validation/QTtTAFqT-no.004/001.jpg
#   inflating: data_final/validation/QTtTAFqT-no.004/115.jpg
#   inflating: data_final/validation/QTtTAFqT-no.004/229.jpg
#   inflating: data_final/validation/QTtTAFqT-no.004/343.jpg
#   inflating: data_final/validation/QTtTAFqT-no.004/annotation.npy
#   inflating: data_final/validation/QTtTAFqT-no.004/transcription_features.npy
#    creating: data_final/validation/Qu81v9Aybv4.000/
#   inflating: data_final/validation/Qu81v9Aybv4.000/001.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.000/115.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.000/229.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.000/343.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.000/annotation.npy
#   inflating: data_final/validation/Qu81v9Aybv4.000/transcription_features.npy
#    creating: data_final/validation/Qu81v9Aybv4.002/
#   inflating: data_final/validation/Qu81v9Aybv4.002/001.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.002/115.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.002/229.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.002/343.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.002/annotation.npy
#   inflating: data_final/validation/Qu81v9Aybv4.002/transcription_features.npy
#    creating: data_final/validation/Qu81v9Aybv4.003/
#   inflating: data_final/validation/Qu81v9Aybv4.003/001.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.003/115.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.003/229.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.003/343.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.003/annotation.npy
#   inflating: data_final/validation/Qu81v9Aybv4.003/transcription_features.npy
#    creating: data_final/validation/Qu81v9Aybv4.004/
#   inflating: data_final/validation/Qu81v9Aybv4.004/001.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.004/115.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.004/229.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.004/343.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.004/annotation.npy
#   inflating: data_final/validation/Qu81v9Aybv4.004/transcription_features.npy
#    creating: data_final/validation/Qu81v9Aybv4.005/
#   inflating: data_final/validation/Qu81v9Aybv4.005/001.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.005/115.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.005/229.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.005/343.jpg
#   inflating: data_final/validation/Qu81v9Aybv4.005/annotation.npy
#   inflating: data_final/validation/Qu81v9Aybv4.005/transcription_features.npy
#    creating: data_final/validation/QuwVzi2tQrQ.005/
#   inflating: data_final/validation/QuwVzi2tQrQ.005/001.jpg
#   inflating: data_final/validation/QuwVzi2tQrQ.005/115.jpg
#   inflating: data_final/validation/QuwVzi2tQrQ.005/229.jpg
#   inflating: data_final/validation/QuwVzi2tQrQ.005/343.jpg
#   inflating: data_final/validation/QuwVzi2tQrQ.005/annotation.npy
#   inflating: data_final/validation/QuwVzi2tQrQ.005/transcription_features.npy
#    creating: data_final/validation/qVcw5-mm31s.000/
#   inflating: data_final/validation/qVcw5-mm31s.000/001.jpg
#   inflating: data_final/validation/qVcw5-mm31s.000/115.jpg
#   inflating: data_final/validation/qVcw5-mm31s.000/229.jpg
#   inflating: data_final/validation/qVcw5-mm31s.000/343.jpg
#   inflating: data_final/validation/qVcw5-mm31s.000/annotation.npy
#   inflating: data_final/validation/qVcw5-mm31s.000/transcription_features.npy
#    creating: data_final/validation/qVcw5-mm31s.004/
#   inflating: data_final/validation/qVcw5-mm31s.004/001.jpg
#   inflating: data_final/validation/qVcw5-mm31s.004/115.jpg
#   inflating: data_final/validation/qVcw5-mm31s.004/229.jpg
#   inflating: data_final/validation/qVcw5-mm31s.004/343.jpg
#   inflating: data_final/validation/qVcw5-mm31s.004/annotation.npy
#   inflating: data_final/validation/qVcw5-mm31s.004/transcription_features.npy
#    creating: data_final/validation/qVcw5-mm31s.005/
#   inflating: data_final/validation/qVcw5-mm31s.005/001.jpg
#   inflating: data_final/validation/qVcw5-mm31s.005/115.jpg
#   inflating: data_final/validation/qVcw5-mm31s.005/229.jpg
#   inflating: data_final/validation/qVcw5-mm31s.005/343.jpg
#   inflating: data_final/validation/qVcw5-mm31s.005/annotation.npy
#   inflating: data_final/validation/qVcw5-mm31s.005/transcription_features.npy
#    creating: data_final/validation/qVrXROy4Ais.000/
#   inflating: data_final/validation/qVrXROy4Ais.000/001.jpg
#   inflating: data_final/validation/qVrXROy4Ais.000/092.jpg
#   inflating: data_final/validation/qVrXROy4Ais.000/183.jpg
#   inflating: data_final/validation/qVrXROy4Ais.000/274.jpg
#   inflating: data_final/validation/qVrXROy4Ais.000/annotation.npy
#   inflating: data_final/validation/qVrXROy4Ais.000/transcription_features.npy
#    creating: data_final/validation/qVrXROy4Ais.001/
#   inflating: data_final/validation/qVrXROy4Ais.001/001.jpg
#   inflating: data_final/validation/qVrXROy4Ais.001/092.jpg
#   inflating: data_final/validation/qVrXROy4Ais.001/183.jpg
#   inflating: data_final/validation/qVrXROy4Ais.001/274.jpg
#   inflating: data_final/validation/qVrXROy4Ais.001/annotation.npy
#   inflating: data_final/validation/qVrXROy4Ais.001/transcription_features.npy
#    creating: data_final/validation/qVrXROy4Ais.004/
#   inflating: data_final/validation/qVrXROy4Ais.004/001.jpg
#   inflating: data_final/validation/qVrXROy4Ais.004/092.jpg
#   inflating: data_final/validation/qVrXROy4Ais.004/183.jpg
#   inflating: data_final/validation/qVrXROy4Ais.004/274.jpg
#   inflating: data_final/validation/qVrXROy4Ais.004/annotation.npy
#   inflating: data_final/validation/qVrXROy4Ais.004/transcription_features.npy
#    creating: data_final/validation/qW0TYVtzq5A.000/
#   inflating: data_final/validation/qW0TYVtzq5A.000/001.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.000/115.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.000/229.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.000/343.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.000/annotation.npy
#   inflating: data_final/validation/qW0TYVtzq5A.000/transcription_features.npy
#    creating: data_final/validation/qW0TYVtzq5A.001/
#   inflating: data_final/validation/qW0TYVtzq5A.001/001.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.001/115.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.001/229.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.001/343.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.001/annotation.npy
#   inflating: data_final/validation/qW0TYVtzq5A.001/transcription_features.npy
#    creating: data_final/validation/qW0TYVtzq5A.002/
#   inflating: data_final/validation/qW0TYVtzq5A.002/001.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.002/115.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.002/229.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.002/343.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.002/annotation.npy
#   inflating: data_final/validation/qW0TYVtzq5A.002/transcription_features.npy
#    creating: data_final/validation/qW0TYVtzq5A.003/
#   inflating: data_final/validation/qW0TYVtzq5A.003/001.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.003/115.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.003/229.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.003/343.jpg
#   inflating: data_final/validation/qW0TYVtzq5A.003/annotation.npy
#   inflating: data_final/validation/qW0TYVtzq5A.003/transcription_features.npy
#    creating: data_final/validation/QXFRE_pjrAE.000/
#   inflating: data_final/validation/QXFRE_pjrAE.000/001.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.000/115.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.000/229.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.000/343.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.000/annotation.npy
#   inflating: data_final/validation/QXFRE_pjrAE.000/transcription_features.npy
#    creating: data_final/validation/QXFRE_pjrAE.001/
#   inflating: data_final/validation/QXFRE_pjrAE.001/001.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.001/115.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.001/229.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.001/343.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.001/annotation.npy
#   inflating: data_final/validation/QXFRE_pjrAE.001/transcription_features.npy
#    creating: data_final/validation/QXFRE_pjrAE.003/
#   inflating: data_final/validation/QXFRE_pjrAE.003/001.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.003/115.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.003/229.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.003/343.jpg
#   inflating: data_final/validation/QXFRE_pjrAE.003/annotation.npy
#   inflating: data_final/validation/QXFRE_pjrAE.003/transcription_features.npy
#    creating: data_final/validation/QyVTG0sGKg0.001/
#   inflating: data_final/validation/QyVTG0sGKg0.001/001.jpg
#   inflating: data_final/validation/QyVTG0sGKg0.001/115.jpg
#   inflating: data_final/validation/QyVTG0sGKg0.001/229.jpg
#   inflating: data_final/validation/QyVTG0sGKg0.001/343.jpg
#   inflating: data_final/validation/QyVTG0sGKg0.001/annotation.npy
#   inflating: data_final/validation/QyVTG0sGKg0.001/transcription_features.npy
#    creating: data_final/validation/QyVTG0sGKg0.002/
#   inflating: data_final/validation/QyVTG0sGKg0.002/001.jpg
#   inflating: data_final/validation/QyVTG0sGKg0.002/115.jpg
#   inflating: data_final/validation/QyVTG0sGKg0.002/229.jpg
#   inflating: data_final/validation/QyVTG0sGKg0.002/343.jpg
#   inflating: data_final/validation/QyVTG0sGKg0.002/annotation.npy
#   inflating: data_final/validation/QyVTG0sGKg0.002/transcription_features.npy
#    creating: data_final/validation/qyzuaettjU8.001/
#   inflating: data_final/validation/qyzuaettjU8.001/001.jpg
#   inflating: data_final/validation/qyzuaettjU8.001/058.jpg
#   inflating: data_final/validation/qyzuaettjU8.001/115.jpg
#   inflating: data_final/validation/qyzuaettjU8.001/172.jpg
#   inflating: data_final/validation/qyzuaettjU8.001/annotation.npy
#   inflating: data_final/validation/qyzuaettjU8.001/transcription_features.npy
#    creating: data_final/validation/qyzuaettjU8.004/
#   inflating: data_final/validation/qyzuaettjU8.004/001.jpg
#   inflating: data_final/validation/qyzuaettjU8.004/058.jpg
#   inflating: data_final/validation/qyzuaettjU8.004/115.jpg
#   inflating: data_final/validation/qyzuaettjU8.004/172.jpg
#   inflating: data_final/validation/qyzuaettjU8.004/annotation.npy
#   inflating: data_final/validation/qyzuaettjU8.004/transcription_features.npy
#    creating: data_final/validation/Qz_cjgCtDcM.001/
#   inflating: data_final/validation/Qz_cjgCtDcM.001/001.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.001/096.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.001/191.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.001/286.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.001/annotation.npy
#   inflating: data_final/validation/Qz_cjgCtDcM.001/transcription_features.npy
#    creating: data_final/validation/Qz_cjgCtDcM.003/
#   inflating: data_final/validation/Qz_cjgCtDcM.003/001.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.003/096.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.003/191.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.003/286.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.003/annotation.npy
#   inflating: data_final/validation/Qz_cjgCtDcM.003/transcription_features.npy
#    creating: data_final/validation/Qz_cjgCtDcM.005/
#   inflating: data_final/validation/Qz_cjgCtDcM.005/001.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.005/096.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.005/191.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.005/286.jpg
#   inflating: data_final/validation/Qz_cjgCtDcM.005/annotation.npy
#   inflating: data_final/validation/Qz_cjgCtDcM.005/transcription_features.npy
#    creating: data_final/validation/Qzu9b49qvKo.003/
#   inflating: data_final/validation/Qzu9b49qvKo.003/001.jpg
#   inflating: data_final/validation/Qzu9b49qvKo.003/115.jpg
#   inflating: data_final/validation/Qzu9b49qvKo.003/229.jpg
#   inflating: data_final/validation/Qzu9b49qvKo.003/343.jpg
#   inflating: data_final/validation/Qzu9b49qvKo.003/annotation.npy
#   inflating: data_final/validation/Qzu9b49qvKo.003/transcription_features.npy
#    creating: data_final/validation/R_6hhFo7M3o.002/
#   inflating: data_final/validation/R_6hhFo7M3o.002/001.jpg
#   inflating: data_final/validation/R_6hhFo7M3o.002/115.jpg
#   inflating: data_final/validation/R_6hhFo7M3o.002/229.jpg
#   inflating: data_final/validation/R_6hhFo7M3o.002/343.jpg
#   inflating: data_final/validation/R_6hhFo7M3o.002/annotation.npy
#   inflating: data_final/validation/R_6hhFo7M3o.002/transcription_features.npy
#    creating: data_final/validation/R_6hhFo7M3o.003/
#   inflating: data_final/validation/R_6hhFo7M3o.003/001.jpg
#   inflating: data_final/validation/R_6hhFo7M3o.003/115.jpg
#   inflating: data_final/validation/R_6hhFo7M3o.003/229.jpg
#   inflating: data_final/validation/R_6hhFo7M3o.003/343.jpg
#   inflating: data_final/validation/R_6hhFo7M3o.003/annotation.npy
#   inflating: data_final/validation/R_6hhFo7M3o.003/transcription_features.npy
#    creating: data_final/validation/r_cVo5qZ9n0.002/
#   inflating: data_final/validation/r_cVo5qZ9n0.002/001.jpg
#   inflating: data_final/validation/r_cVo5qZ9n0.002/115.jpg
#   inflating: data_final/validation/r_cVo5qZ9n0.002/229.jpg
#   inflating: data_final/validation/r_cVo5qZ9n0.002/343.jpg
#   inflating: data_final/validation/r_cVo5qZ9n0.002/annotation.npy
#   inflating: data_final/validation/r_cVo5qZ9n0.002/transcription_features.npy
#    creating: data_final/validation/R_LJX7wszPY.000/
#   inflating: data_final/validation/R_LJX7wszPY.000/001.jpg
#   inflating: data_final/validation/R_LJX7wszPY.000/115.jpg
#   inflating: data_final/validation/R_LJX7wszPY.000/229.jpg
#   inflating: data_final/validation/R_LJX7wszPY.000/343.jpg
#   inflating: data_final/validation/R_LJX7wszPY.000/annotation.npy
#   inflating: data_final/validation/R_LJX7wszPY.000/transcription_features.npy
#    creating: data_final/validation/R0RURVpmU9M.004/
#   inflating: data_final/validation/R0RURVpmU9M.004/001.jpg
#   inflating: data_final/validation/R0RURVpmU9M.004/096.jpg
#   inflating: data_final/validation/R0RURVpmU9M.004/191.jpg
#   inflating: data_final/validation/R0RURVpmU9M.004/286.jpg
#   inflating: data_final/validation/R0RURVpmU9M.004/annotation.npy
#   inflating: data_final/validation/R0RURVpmU9M.004/transcription_features.npy
#    creating: data_final/validation/r1v6EmZv7-o.001/
#   inflating: data_final/validation/r1v6EmZv7-o.001/001.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.001/096.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.001/191.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.001/286.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.001/annotation.npy
#   inflating: data_final/validation/r1v6EmZv7-o.001/transcription_features.npy
#    creating: data_final/validation/r1v6EmZv7-o.002/
#   inflating: data_final/validation/r1v6EmZv7-o.002/001.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.002/096.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.002/191.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.002/286.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.002/annotation.npy
#   inflating: data_final/validation/r1v6EmZv7-o.002/transcription_features.npy
#    creating: data_final/validation/r1v6EmZv7-o.004/
#   inflating: data_final/validation/r1v6EmZv7-o.004/001.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.004/096.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.004/191.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.004/286.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.004/annotation.npy
#   inflating: data_final/validation/r1v6EmZv7-o.004/transcription_features.npy
#    creating: data_final/validation/r1v6EmZv7-o.005/
#   inflating: data_final/validation/r1v6EmZv7-o.005/001.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.005/096.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.005/191.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.005/286.jpg
#   inflating: data_final/validation/r1v6EmZv7-o.005/annotation.npy
#   inflating: data_final/validation/r1v6EmZv7-o.005/transcription_features.npy
#    creating: data_final/validation/r1YAW67aevY.000/
#   inflating: data_final/validation/r1YAW67aevY.000/001.jpg
#   inflating: data_final/validation/r1YAW67aevY.000/092.jpg
#   inflating: data_final/validation/r1YAW67aevY.000/183.jpg
# ...
#   inflating: data_final/validation/uATtAHyVSMM.003/343.jpg
#   inflating: data_final/validation/uATtAHyVSMM.003/annotation.npy
#   inflating: data_final/validation/uATtAHyVSMM.003/transcription_features.npy
#    creating: data_final/validation/uATtAHyVSMM.005/
#   inflating: data_final/validation/uATtAHyVSMM.005/001.jpg
#   inflating: data_final/validation/uATtAHyVSMM.005/115.jpg
#   inflating: data_final/validation/uATtAHyVSMM.005/229.jpg
#   inflating: data_final/validation/uATtAHyVSMM.005/343.jpg
#   inflating: data_final/validation/uATtAHyVSMM.005/annotation.npy
#   inflating: data_final/validation/uATtAHyVSMM.005/transcription_features.npy
#    creating: data_final/validation/uCJNAX_b9mc.000/
#   inflating: data_final/validation/uCJNAX_b9mc.000/001.jpg
#   inflating: data_final/validation/uCJNAX_b9mc.000/096.jpg
#   inflating: data_final/validation/uCJNAX_b9mc.000/191.jpg
#   inflating: data_final/validation/uCJNAX_b9mc.000/286.jpg
#   inflating: data_final/validation/uCJNAX_b9mc.000/annotation.npy
#   inflating: data_final/validation/uCJNAX_b9mc.000/transcription_features.npy
#    creating: data_final/validation/uCJNAX_b9mc.002/
#   inflating: data_final/validation/uCJNAX_b9mc.002/001.jpg
#   inflating: data_final/validation/uCJNAX_b9mc.002/096.jpg
#   inflating: data_final/validation/uCJNAX_b9mc.002/191.jpg
#   inflating: data_final/validation/uCJNAX_b9mc.002/286.jpg
#   inflating: data_final/validation/uCJNAX_b9mc.002/annotation.npy
#   inflating: data_final/validation/uCJNAX_b9mc.002/transcription_features.npy
#    creating: data_final/validation/UCKiPkp4ZkA.000/
#   inflating: data_final/validation/UCKiPkp4ZkA.000/001.jpg
#   inflating: data_final/validation/UCKiPkp4ZkA.000/115.jpg
#   inflating: data_final/validation/UCKiPkp4ZkA.000/229.jpg
#   inflating: data_final/validation/UCKiPkp4ZkA.000/343.jpg
#   inflating: data_final/validation/UCKiPkp4ZkA.000/annotation.npy
#   inflating: data_final/validation/UCKiPkp4ZkA.000/transcription_features.npy
#    creating: data_final/validation/UcyjGGEBn30.001/
#   inflating: data_final/validation/UcyjGGEBn30.001/001.jpg
#   inflating: data_final/validation/UcyjGGEBn30.001/096.jpg
#   inflating: data_final/validation/UcyjGGEBn30.001/191.jpg
#   inflating: data_final/validation/UcyjGGEBn30.001/286.jpg
#   inflating: data_final/validation/UcyjGGEBn30.001/annotation.npy
#   inflating: data_final/validation/UcyjGGEBn30.001/transcription_features.npy
#    creating: data_final/validation/UcyjGGEBn30.004/
#   inflating: data_final/validation/UcyjGGEBn30.004/001.jpg
#   inflating: data_final/validation/UcyjGGEBn30.004/096.jpg
#   inflating: data_final/validation/UcyjGGEBn30.004/191.jpg
#   inflating: data_final/validation/UcyjGGEBn30.004/286.jpg
#   inflating: data_final/validation/UcyjGGEBn30.004/annotation.npy
#   inflating: data_final/validation/UcyjGGEBn30.004/transcription_features.npy
#    creating: data_final/validation/UcyjGGEBn30.005/
#   inflating: data_final/validation/UcyjGGEBn30.005/001.jpg
#   inflating: data_final/validation/UcyjGGEBn30.005/096.jpg
#   inflating: data_final/validation/UcyjGGEBn30.005/191.jpg
#   inflating: data_final/validation/UcyjGGEBn30.005/286.jpg
#   inflating: data_final/validation/UcyjGGEBn30.005/annotation.npy
#   inflating: data_final/validation/UcyjGGEBn30.005/transcription_features.npy
#    creating: data_final/validation/UD-8YYU7GZs.000/
#   inflating: data_final/validation/UD-8YYU7GZs.000/001.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.000/115.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.000/229.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.000/343.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.000/annotation.npy
#   inflating: data_final/validation/UD-8YYU7GZs.000/transcription_features.npy
#    creating: data_final/validation/UD-8YYU7GZs.003/
#   inflating: data_final/validation/UD-8YYU7GZs.003/001.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.003/115.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.003/229.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.003/343.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.003/annotation.npy
#   inflating: data_final/validation/UD-8YYU7GZs.003/transcription_features.npy
#    creating: data_final/validation/UD-8YYU7GZs.004/
#   inflating: data_final/validation/UD-8YYU7GZs.004/001.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.004/115.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.004/229.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.004/343.jpg
#   inflating: data_final/validation/UD-8YYU7GZs.004/annotation.npy
#   inflating: data_final/validation/UD-8YYU7GZs.004/transcription_features.npy
#    creating: data_final/validation/udn-L92wdn8.000/
#   inflating: data_final/validation/udn-L92wdn8.000/001.jpg
#   inflating: data_final/validation/udn-L92wdn8.000/057.jpg
#   inflating: data_final/validation/udn-L92wdn8.000/114.jpg
#   inflating: data_final/validation/udn-L92wdn8.000/171.jpg
#   inflating: data_final/validation/udn-L92wdn8.000/annotation.npy
#   inflating: data_final/validation/udn-L92wdn8.000/transcription_features.npy
#    creating: data_final/validation/uE2U_Y7QrIw.000/
#   inflating: data_final/validation/uE2U_Y7QrIw.000/001.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.000/115.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.000/229.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.000/343.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.000/annotation.npy
#   inflating: data_final/validation/uE2U_Y7QrIw.000/transcription_features.npy
#    creating: data_final/validation/uE2U_Y7QrIw.002/
#   inflating: data_final/validation/uE2U_Y7QrIw.002/001.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.002/115.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.002/229.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.002/343.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.002/annotation.npy
#   inflating: data_final/validation/uE2U_Y7QrIw.002/transcription_features.npy
#    creating: data_final/validation/uE2U_Y7QrIw.003/
#   inflating: data_final/validation/uE2U_Y7QrIw.003/001.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.003/115.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.003/229.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.003/343.jpg
#   inflating: data_final/validation/uE2U_Y7QrIw.003/annotation.npy
#   inflating: data_final/validation/uE2U_Y7QrIw.003/transcription_features.npy
#    creating: data_final/validation/UEYKBC_SuzU.001/
#   inflating: data_final/validation/UEYKBC_SuzU.001/001.jpg
#   inflating: data_final/validation/UEYKBC_SuzU.001/092.jpg
#   inflating: data_final/validation/UEYKBC_SuzU.001/183.jpg
#   inflating: data_final/validation/UEYKBC_SuzU.001/274.jpg
#   inflating: data_final/validation/UEYKBC_SuzU.001/annotation.npy
#   inflating: data_final/validation/UEYKBC_SuzU.001/transcription_features.npy
#    creating: data_final/validation/UEYKBC_SuzU.004/
#   inflating: data_final/validation/UEYKBC_SuzU.004/001.jpg
#   inflating: data_final/validation/UEYKBC_SuzU.004/092.jpg
#   inflating: data_final/validation/UEYKBC_SuzU.004/183.jpg
#   inflating: data_final/validation/UEYKBC_SuzU.004/274.jpg
#   inflating: data_final/validation/UEYKBC_SuzU.004/annotation.npy
#   inflating: data_final/validation/UEYKBC_SuzU.004/transcription_features.npy
#    creating: data_final/validation/uf_sIIw4zxY.001/
#   inflating: data_final/validation/uf_sIIw4zxY.001/001.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.001/096.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.001/191.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.001/286.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.001/annotation.npy
#   inflating: data_final/validation/uf_sIIw4zxY.001/transcription_features.npy
#    creating: data_final/validation/uf_sIIw4zxY.002/
#   inflating: data_final/validation/uf_sIIw4zxY.002/001.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.002/096.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.002/191.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.002/286.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.002/annotation.npy
#   inflating: data_final/validation/uf_sIIw4zxY.002/transcription_features.npy
#    creating: data_final/validation/uf_sIIw4zxY.005/
#   inflating: data_final/validation/uf_sIIw4zxY.005/001.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.005/096.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.005/191.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.005/286.jpg
#   inflating: data_final/validation/uf_sIIw4zxY.005/annotation.npy
#   inflating: data_final/validation/uf_sIIw4zxY.005/transcription_features.npy
#    creating: data_final/validation/UGn9Q8Fe9jw.001/
#   inflating: data_final/validation/UGn9Q8Fe9jw.001/001.jpg
#   inflating: data_final/validation/UGn9Q8Fe9jw.001/115.jpg
#   inflating: data_final/validation/UGn9Q8Fe9jw.001/229.jpg
#   inflating: data_final/validation/UGn9Q8Fe9jw.001/343.jpg
#   inflating: data_final/validation/UGn9Q8Fe9jw.001/annotation.npy
#   inflating: data_final/validation/UGn9Q8Fe9jw.001/transcription_features.npy
#    creating: data_final/validation/UGp1GNK0GWg.000/
#   inflating: data_final/validation/UGp1GNK0GWg.000/001.jpg
#   inflating: data_final/validation/UGp1GNK0GWg.000/115.jpg
#   inflating: data_final/validation/UGp1GNK0GWg.000/229.jpg
#   inflating: data_final/validation/UGp1GNK0GWg.000/343.jpg
#   inflating: data_final/validation/UGp1GNK0GWg.000/annotation.npy
#   inflating: data_final/validation/UGp1GNK0GWg.000/transcription_features.npy
#    creating: data_final/validation/UGsr6Vnqf7I.003/
#   inflating: data_final/validation/UGsr6Vnqf7I.003/001.jpg
#   inflating: data_final/validation/UGsr6Vnqf7I.003/115.jpg
#   inflating: data_final/validation/UGsr6Vnqf7I.003/229.jpg
#   inflating: data_final/validation/UGsr6Vnqf7I.003/343.jpg
#   inflating: data_final/validation/UGsr6Vnqf7I.003/annotation.npy
#   inflating: data_final/validation/UGsr6Vnqf7I.003/transcription_features.npy
#    creating: data_final/validation/UGsr6Vnqf7I.004/
#   inflating: data_final/validation/UGsr6Vnqf7I.004/001.jpg
#   inflating: data_final/validation/UGsr6Vnqf7I.004/115.jpg
#   inflating: data_final/validation/UGsr6Vnqf7I.004/229.jpg
#   inflating: data_final/validation/UGsr6Vnqf7I.004/343.jpg
#   inflating: data_final/validation/UGsr6Vnqf7I.004/annotation.npy
#   inflating: data_final/validation/UGsr6Vnqf7I.004/transcription_features.npy
#    creating: data_final/validation/UhNyHUwo1SY.001/
#   inflating: data_final/validation/UhNyHUwo1SY.001/001.jpg
#   inflating: data_final/validation/UhNyHUwo1SY.001/115.jpg
#   inflating: data_final/validation/UhNyHUwo1SY.001/229.jpg
#   inflating: data_final/validation/UhNyHUwo1SY.001/343.jpg
#   inflating: data_final/validation/UhNyHUwo1SY.001/annotation.npy
#   inflating: data_final/validation/UhNyHUwo1SY.001/transcription_features.npy
#    creating: data_final/validation/UhNyHUwo1SY.003/
#   inflating: data_final/validation/UhNyHUwo1SY.003/001.jpg
#   inflating: data_final/validation/UhNyHUwo1SY.003/115.jpg
#   inflating: data_final/validation/UhNyHUwo1SY.003/229.jpg
#   inflating: data_final/validation/UhNyHUwo1SY.003/343.jpg
#   inflating: data_final/validation/UhNyHUwo1SY.003/annotation.npy
#   inflating: data_final/validation/UhNyHUwo1SY.003/transcription_features.npy
#    creating: data_final/validation/uHrP02iwW1o.000/
#   inflating: data_final/validation/uHrP02iwW1o.000/001.jpg
#   inflating: data_final/validation/uHrP02iwW1o.000/115.jpg
#   inflating: data_final/validation/uHrP02iwW1o.000/229.jpg
#   inflating: data_final/validation/uHrP02iwW1o.000/343.jpg
#   inflating: data_final/validation/uHrP02iwW1o.000/annotation.npy
#   inflating: data_final/validation/uHrP02iwW1o.000/transcription_features.npy
#    creating: data_final/validation/uHrP02iwW1o.002/
#   inflating: data_final/validation/uHrP02iwW1o.002/001.jpg
#   inflating: data_final/validation/uHrP02iwW1o.002/115.jpg
#   inflating: data_final/validation/uHrP02iwW1o.002/229.jpg
#   inflating: data_final/validation/uHrP02iwW1o.002/343.jpg
#   inflating: data_final/validation/uHrP02iwW1o.002/annotation.npy
#   inflating: data_final/validation/uHrP02iwW1o.002/transcription_features.npy
#    creating: data_final/validation/Ui1ajQU5Ib8.000/
#   inflating: data_final/validation/Ui1ajQU5Ib8.000/001.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.000/115.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.000/229.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.000/343.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.000/annotation.npy
#   inflating: data_final/validation/Ui1ajQU5Ib8.000/transcription_features.npy
#    creating: data_final/validation/Ui1ajQU5Ib8.001/
#   inflating: data_final/validation/Ui1ajQU5Ib8.001/001.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.001/115.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.001/229.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.001/343.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.001/annotation.npy
#   inflating: data_final/validation/Ui1ajQU5Ib8.001/transcription_features.npy
#    creating: data_final/validation/Ui1ajQU5Ib8.005/
#   inflating: data_final/validation/Ui1ajQU5Ib8.005/001.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.005/115.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.005/229.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.005/343.jpg
#   inflating: data_final/validation/Ui1ajQU5Ib8.005/annotation.npy
#   inflating: data_final/validation/Ui1ajQU5Ib8.005/transcription_features.npy
#    creating: data_final/validation/uifW-cV-iQo.002/
#   inflating: data_final/validation/uifW-cV-iQo.002/001.jpg
#   inflating: data_final/validation/uifW-cV-iQo.002/096.jpg
#   inflating: data_final/validation/uifW-cV-iQo.002/191.jpg
#   inflating: data_final/validation/uifW-cV-iQo.002/286.jpg
#   inflating: data_final/validation/uifW-cV-iQo.002/annotation.npy
#   inflating: data_final/validation/uifW-cV-iQo.002/transcription_features.npy
#    creating: data_final/validation/UipoC_HLOP0.001/
#   inflating: data_final/validation/UipoC_HLOP0.001/001.jpg
#   inflating: data_final/validation/UipoC_HLOP0.001/092.jpg
#   inflating: data_final/validation/UipoC_HLOP0.001/183.jpg
#   inflating: data_final/validation/UipoC_HLOP0.001/274.jpg
#   inflating: data_final/validation/UipoC_HLOP0.001/annotation.npy
#   inflating: data_final/validation/UipoC_HLOP0.001/transcription_features.npy
#    creating: data_final/validation/UipoC_HLOP0.003/
#   inflating: data_final/validation/UipoC_HLOP0.003/001.jpg
#   inflating: data_final/validation/UipoC_HLOP0.003/092.jpg
#   inflating: data_final/validation/UipoC_HLOP0.003/183.jpg
#   inflating: data_final/validation/UipoC_HLOP0.003/274.jpg
#   inflating: data_final/validation/UipoC_HLOP0.003/annotation.npy
#   inflating: data_final/validation/UipoC_HLOP0.003/transcription_features.npy
#    creating: data_final/validation/UipoC_HLOP0.004/
#   inflating: data_final/validation/UipoC_HLOP0.004/001.jpg
#   inflating: data_final/validation/UipoC_HLOP0.004/092.jpg
#   inflating: data_final/validation/UipoC_HLOP0.004/183.jpg
#   inflating: data_final/validation/UipoC_HLOP0.004/274.jpg
#   inflating: data_final/validation/UipoC_HLOP0.004/annotation.npy
#   inflating: data_final/validation/UipoC_HLOP0.004/transcription_features.npy
#   inflating: test.txt
#   inflating: train.txt
#   inflating: validation.txt
# --2023-07-17 09:56:14--  https://data.chalearnlap.cvc.uab.cat/Colab_2021/UBmasterBDS/myfunctions.py
# Resolving data.chalearnlap.cvc.uab.cat (data.chalearnlap.cvc.uab.cat)... 158.109.8.102
# Connecting to data.chalearnlap.cvc.uab.cat (data.chalearnlap.cvc.uab.cat)|158.109.8.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3207 (3.1K) [application/octet-stream]
# Saving to: ‘myfunctions.py’
#
# myfunctions.py      100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2023-07-17 09:56:14 (740 MB/s) - ‘myfunctions.py’ saved [3207/3207]

# %%
import tensorflow as tf
from tensorflow.keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, BatchNormalization, ReLU, LeakyReLU, LSTM, Reshape, GlobalMaxPooling1D, GlobalAveragePooling1D, Concatenate
import keras.backend as K
import numpy as np
import tensorflow.keras.applications as app
# from tensorflow.keras.models import Model
# import reimplemented Model class
from myfunctions import MyModel, reshape
from glob import glob
import cv2

n_frames = 4
if n_frames>4:
  print("n_frames must be between 1 and 4. It is set to 4.")
  n_frames = 4
elif n_frames<1:
  print("n_frames must be between 1 and 4. It is set to 1.")
  n_frames = 1

# %% [markdown]
# ## **Definiendo nuestra clase "DataGenerator" para cargar los datos en lotes**
#
# Nuestra clase "DataGenerator" se inicializa con varias variables de entrada:
# - **data_list**, que es una lista de nombres de archivos de video para conjuntos de entrenamiento, validación o prueba,
# - **root** es la ruta al conjunto de destino (es decir, entrenamiento, validación o prueba),
# - **n_frames** indica el número de imágenes por vídeo,
# - **is_sequence** indica si las características de transcripción se dan como una secuencia de tokens o como promedio,
# - **batch_size** es el tamaño del lote,
# - **shuffle** indica si la lista de datos está desordenada o no (es habitual desordenar las muestras para que el algoritmo de aprendizaje reciba un orden diferente de muestras en cada epoch).
#
# Los datos devueltos son una lista con datos de imagen y texto con la forma de **(batch_size, n_frames, 224, 224, 3)** para imágenes y **(batch_size, 114, 768)** o **(batch_size, 768)** dependiendo de **is_sequence**.

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, data_list, root, n_frames=4, is_sequence=True, batch_size=16, shuffle=True):
        super().__init__()
        'Initialization'
        self.data_list = data_list
        self.root = root
        self.n_frames = n_frames
        self.is_sequence = is_sequence
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.mean = np.array([[[103.939, 116.779, 123.68]]], dtype=np.float32)
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.data_list) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Find list of IDs
        data_list_temp = self.getdatalist(index)

        # Generate data
        X, y = self.__data_generation(data_list_temp)

        return X, y

    def getdatalist(self, index):
        'Get the list of data for one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        data_list_batch = [self.data_list[k] for k in indexes]

        return data_list_batch

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.data_list))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, data_list):
      'Generates data containing batch_size samples' # X_img : (batch_size, n_frames, 224, 224, 3,), X_txt : (batch_size, 768)
      X_img, X_txt, Y = [], [], []
      n_max = 114
      for f in data_list:
        text_features = np.load(open(self.root+f+'/transcription_features.npy', 'rb'))[0]
        if self.is_sequence:
          n_seq, n_feat = text_features.shape
          # if the number of tokens is smaller than the maximum number of tokens,...
          # we pad the features with zero to have a fixed length sequence
          if n_seq < n_max:
            text_features = np.concatenate([np.zeros((n_max - n_seq, n_feat)), text_features], axis=0)
        else:
          text_features = np.mean(text_features, axis=0)
        X_txt.append(text_features)

        files = sorted(glob(self.root+f+'/*.jpg'))
        imgs = []
        for i in range(self.n_frames):
          img = cv2.imread(files[i])
          img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32) - self.mean
          imgs.append(img)
        X_img.append(imgs)

        # ['extraversion', 'neuroticism', 'agreeableness', 'conscientiousness', 'openness']
        traits = np.load(open(self.root+f+'/annotation.npy', 'rb'))
        Y.append(traits)

      return [np.array(X_img, np.float32), np.array(X_txt, np.float32)], np.array(Y, np.float32)

# %% [markdown]
# ## **Construyendo nuestro modelo de red neuronal**
#
# - Para diseñar nuestra red multimodal, usamos el conocimiento que obtuvimos en los Jupyter Notebooks anteriores. Definimos dos entradas para características de imagen y texto que se le dan a la clase "MyModel" para construir el modelo. Las imágenes y las características textuales son procesadas por ResNet50 y LSTM respectivamente. Las formas de salida de cada uno son **(batch_size, 2048)** y **(batch_size, 768)**.
# - Antes de fusionar las características de las dos modalidades, realizamos una capa de proyección sobre estas representaciones de características. Primero se aplica una capa Densa para reducir la dimensionalidad (definida por **projection_dims**) y luego se realiza una secuencia de bloques Densos residuales ("Activation+Dense+Dropout") definida por **num_projection_layers**.
# - Estas capas de proyección, que incluyen la reducción de la dimensionalidad y las conexiones residuales, ayudan a equilibrar las características entre dos modalidades mientras se tiene un entrenamiento estable y menos sobreajustado.
# - Finalmente, las representaciones proyectadas deben fusionarse. Una fusión simple pero efectiva es la concatenación, lo que significa apilar las dos características en un vector de características con forma **(batch_size, F1+F2)** donde F1 y F2 son el número de características para las modalidades después de las capas de proyección. Al final, se utiliza una regresión simple MLP para predecir los rasgos de personalidad.

# %%
def project_embeddings(embeddings, num_projection_layers, projection_dims, dropout_rate):
    projected_embeddings = tf.keras.layers.Dense(units=projection_dims)(embeddings)
    for _ in range(num_projection_layers):
        x = tf.nn.gelu(projected_embeddings)
        x = tf.keras.layers.Dense(projection_dims)(x)
        x = tf.keras.layers.Dropout(dropout_rate)(x)
        x = tf.keras.layers.Add()([projected_embeddings, x])
        projected_embeddings = tf.keras.layers.LayerNormalization()(x)
    return projected_embeddings

# %%
is_sequential = True

# Create model
def create_model(is_sequential):

    net_name = ['resnet50','ResNet50']

    # Select the corresponding network class
    mynet = getattr(getattr(app, net_name[0]), net_name[1])

    base_model = mynet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    input_img = tf.keras.Input(shape=(n_frames, 224, 224, 3))

    x = reshape(n_frames)(input_img)#(batch_size*n_frames, 224, 224, 3)

    x = base_model(x)#(batch_size*n_frames, 7, 7, 2048)

    # add a global spatial max pooling layer among all frames of a video after reshaping the features
    x = reshape(n_frames)(x)#(batch_size, n_frames*7*7, 2048)
    # x = GlobalMaxPooling1D()(x)#(batch_size, 2048)
    x = GlobalAveragePooling1D()(x)#(batch_size, 2048)
    x1 = project_embeddings(x, 1, 512, 0.3)#(batch_size, 512)

    # Process the textual data
    if is_sequential:
      input_txt = tf.keras.Input(shape=(114, 768))# (batch_size, 114, 768)

      x = LSTM(768, input_shape=(114, 768), activation=None, return_sequences=True)(input_txt)# (batch_size, 114, 768)
      x = Dropout(0.2)(x)

      x = LSTM(768, activation=None)(x)# (batch_size, 768)
      x2 = project_embeddings(x, 1, 512, 0.3)# (batch_size, 512)
    else:
      input_txt = tf.keras.Input(shape=(768,))# (batch_size, 768)

      x2 = project_embeddings(x, 1, 512, 0.3)# (batch_size, 512)

    x = Concatenate()([x1, x2])

    x = Dropout(0.5)(x)
    fc_1 = Dense(256, activation='relu')(x)
    predictions = Dense(5, activation='sigmoid')(fc_1)

    # this is the model we will train
    model = MyModel(inputs=(input_img, input_txt), outputs=predictions)

    return model

model = create_model(is_sequential)
# print(model.summary())
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Leyendo la lista de archivos de entrenamiento, validación y prueba

# %%
# Read the data lists
with open('train.txt', 'r') as f:
  train_list = f.readlines()
  for i in range(len(train_list)):
    train_list[i] = train_list[i].rsplit('\n',1)[0]
with open('validation.txt', 'r') as f:
  validation_list = f.readlines()
  for i in range(len(validation_list)):
    validation_list[i] = validation_list[i].rsplit('\n',1)[0]
with open('test.txt', 'r') as f:
  test_list = f.readlines()
  for i in range(len(test_list)):
    test_list[i] = test_list[i].rsplit('\n',1)[0]

# %% [markdown]
# ## Entrenando y evaluando nuestro modelo
#
# El modelo se entrena con el optimizador Adam con una tasa de aprendizaje de 1e-5 y una función de pérdida de error cuadrático medio (L2). El tamaño del lote es 32 y el modelo se entrena durante 20 epochs. Se define un "callback" para guardar el mejor modelo entrenado, en función del error absoluto medio observado en el conjunto de validación. Finalmente, se guarda el registro del historial en la ruta definida y se evalúa el modelo en el conjunto de pruebas.

# %%
# Training
import gc
import random
import pickle

lr = 1e-5
batch_size = 32
n_epochs = 20
checkpoint = './best_model_multimodal.h5'
shuffle = True
verbose = 1

n_frames = 4  # Setting number of images per video to 4

# creating data generators to load the data
train_dg = DataGenerator(train_list, './data_final/train/', n_frames=n_frames, is_sequence=is_sequential, batch_size=batch_size, shuffle=shuffle)
validation_dg = DataGenerator(validation_list, './data_final/validation/', n_frames=n_frames, is_sequence=is_sequential, batch_size=batch_size, shuffle=False)
test_dg = DataGenerator(test_list, './data_final/test/', n_frames=n_frames, is_sequence=is_sequential, batch_size=batch_size, shuffle=False)

# defining the optimizer
model.compile(tf.keras.optimizers.Adam(learning_rate=lr), loss=tf.keras.losses.MeanSquaredError(), metrics=['mae'])

history = model.fit(train_dg, validation_dg, epochs=n_epochs, verbose=verbose, checkpoint=checkpoint)

with open('./train_history_multimodal.pkl', 'wb') as handle:
  pickle.dump(history, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Ceating/building our model again, and loading the last checkpoint (best model)
model = create_model(is_sequential)
model.load_weights(checkpoint)
model.compile(tf.keras.optimizers.Adam(learning_rate=lr), loss=tf.keras.losses.MeanSquaredError(), metrics=['mae'])

# Evaluate the trained model on the test set

# Some house keeping
gc.collect()
tf.keras.backend.clear_session()

print('Evaluating on the test set')

_loss = 0
_mae = 0
for step in range(test_dg.__len__()):
  # Load the batch
  X, Y = test_dg.__getitem__(step)
  X = [tf.convert_to_tensor(x, dtype=tf.float32) for x in X]
  Y = tf.convert_to_tensor(Y, dtype=tf.float32)

  # validate on one batch
  loss, mae = model.evaluate(X, Y, verbose = 0)

  _loss += loss
  _mae += mae
step += 1
print("The final mean absolute error is {0:.5f}\n".format(_mae/step))

# %% [markdown]
# ## Visualización del historial de entrenamiento
# - Pérdida de entrenamiento y validación, y MAE para cada epoch.

# %%
# Visualization
from matplotlib import pyplot as plt

train_hist = pickle.load(open('./train_history_multimodal.pkl',"rb"))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 4))
fig.suptitle('Training history', fontsize=14, fontweight='bold')

ax1.plot(train_hist['loss'])
ax1.plot(train_hist['val_loss'])
ax1.set(xlabel='epoch', ylabel='Loss')
ax1.legend(['train', 'valid'], loc='upper right')

ax2.plot(train_hist['mae'])
ax2.plot(train_hist['val_mae'])
ax2.set(xlabel='epoch', ylabel='MAE')
ax2.legend(['train', 'valid'], loc='upper right')

# %% [markdown]
# ## Visualizando una muestra de predicción

# %%
# Download the original video transcriptions
# !wget http://158.109.8.102/FirstImpressionsV2/train-transcription.zip
# !unzip train-transcription.zip

from glob import glob
import cv2
import numpy as np
import pickle
from matplotlib import pyplot as plt

print('Predicting on the first batch of the test set')
# Load the batch
step = 0
X, Y = test_dg.__getitem__(step)

# validate on one batch
predictions = model.predict([tf.convert_to_tensor(x, dtype=tf.float32) for x in X])

# Visualize an example prediction
root = './data_final/test/'
sample_in_batch = 0 # You can increase this number up to the batch_size-1
vid_name = test_dg.getdatalist(step)[sample_in_batch]

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(15, 4))
fig.suptitle('Sampled images from '+vid_name, fontsize=14, fontweight='bold')

# reading and showing images
files = sorted(glob(root+vid_name+'/*.jpg'))
for i in range(4):
  img = cv2.imread(files[i])
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  eval('ax'+str(i+1)).imshow(img)

# reading and printing the transcription
trans = pickle.load(open('transcription_training.pkl','rb'))
print('\n\n\nTranscription is')
print(trans[vid_name+'.mp4'])

# reading and printing the personality labels
traits = np.load(open(root+vid_name+'/annotation.npy', 'rb'))
print('\nApparent personality labels are')
print('\t\textraversion\tneuroticism\tagreeableness\tconscientiousness\topenness')
print('Labels\t\t{0:0.2f}\t\t{1:0.2f}\t\t{2:0.2f}\t\t{3:0.2f}\t\t\t{4:0.2f}\t\t'.format(traits[0],traits[1],traits[2],traits[3],traits[4]))
print('Predictions\t{0:0.2f}\t\t{1:0.2f}\t\t{2:0.2f}\t\t{3:0.2f}\t\t\t{4:0.2f}\t\t'.format(predictions[sample_in_batch][0],predictions[sample_in_batch][1],predictions[sample_in_batch][2],predictions[sample_in_batch][3],predictions[sample_in_batch][4]))
